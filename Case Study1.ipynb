# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\Adrash\\Documents\\Python\\cars_data.csv')
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               10000 non-null  object
#  1   Model              10000 non-null  object
#  2   Nickname           10000 non-null  object
#  3   Car Gender         10000 non-null  object
#  4   Buyer Gender       10000 non-null  object
#  5   Buyer Age          10000 non-null  int64
#  6   Buzzword           10000 non-null  object
#  7   Country            10000 non-null  object
#  8   City               10000 non-null  object
#  9   Dealer Latitude    10000 non-null  float64
#  10  Dealer Longitude   10000 non-null  float64
#  11  Color              10000 non-null  object
#  12  New Car            10000 non-null  bool
#  13  Purchase Date      10000 non-null  object
#  14  Sale Price         10000 non-null  float64
#  15  Discount           10000 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %%
data1=data.isnull()
data1.sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %%
sns.catplot(x=data['Buyer Gender'],data=data, kind="count",height=6, aspect=.5)
plt.title('Male vs Female \nBuyers participated in the Sales',fontsize=16)
plt.ylabel('Count',fontsize=12)
plt.xlabel('Buyer Gender',fontsize=12)
plt.grid(linestyle='--',linewidth=.7)

# %%
data2=data.sort_values('Sale Price',ascending=False)
data3=data2[0:5]
data3
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %%
print('top 5 cars based on their sales price are\n',data3['Make'])
# Out:
# top 5 cars based on their sales price are
#  5984    Volkswagen
# 1270          Audi
# 3460         Lexus
# 9032         Mazda
# 302          Lexus
# Name: Make, dtype: object

# %%
data4=data.sort_values('Sale Price',ascending=True)[0:5]

data4
# Out:
#          Make                 Model Nickname Car Gender Buyer Gender  \
# 3513      Geo               Tracker   Nowell       Male         Male
# 7234     Ford             Excursion   Patric       Male         Male
# 5956    Mazda                Mazda6   Milzie       Male       Female
# 6270   Nissan                 240SX   Paloma       Male       Female
# 6241  Lincoln  Continental Mark VII  Malissa     Female       Female
#
#       Buyer Age              Buzzword      Country        City  \
# 3513         64             impactful        Japan        Hagi
# 7234         30         Decentralized   Azerbaijan    Zaqatala
# 5956         39            motivating      Albania       Shezë
# 6270         48         Self-enabling  Philippines       Lanas
# 6241         57  budgetary management       Russia  Safakulevo
#
#       Dealer Latitude  Dealer Longitude      Color  New Car Purchase Date  \
# 3513        32.428624        130.649340     Orange     True    28/01/2016
# ...

# %%
print('Least 5 cars based on their sales price are\n',data4['Make'])
# Out:
# Least 5 cars based on their sales price are
#  3513        Geo
# 7234       Ford
# 5956      Mazda
# 6270     Nissan
# 6241    Lincoln
# Name: Make, dtype: object
